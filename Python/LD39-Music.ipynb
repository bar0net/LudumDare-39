# %%
## Script to generate some music for LD39

from music21 import *
import os

_MUSIC_PATH_ = "./music/"
os.makedirs(_MUSIC_PATH_, exist_ok=True)

# %%
output = stream.Stream()

s = stream.Part();

s.append( note.Rest(quarterLength=1.0))  # 1
s.append( note.Note('a', octave=6, quarterLength=.125) )
s.append( note.Note('a-', octave=6, quarterLength=.125) )
s.append( note.Note('a', octave=6, quarterLength=.125) )
s.append( note.Note('a-', octave=6, quarterLength=.125) )
s.append( note.Note('f', octave=6, quarterLength=.5) ) #2
s.append( note.Rest(quarterLength=1.0)) #3


s.append( note.Note('f', octave=6, quarterLength=.125) )
s.append( note.Note('f-', octave=6, quarterLength=.125) ) #3
s.append( note.Note('f', octave=6, quarterLength=.125) )
s.append( note.Note('f-', octave=6, quarterLength=.125) )
s.append( note.Note('f', octave=6, quarterLength=.125) )
s.append( note.Note('g-', octave=6, quarterLength=.125) ) #4
s.append( note.Note('g', octave=6, quarterLength=.125) )
s.append( note.Note('g-', octave=6, quarterLength=.125) ) 
s.append( note.Note('f', octave=6, quarterLength=.125) )
s.append( note.Note('f-', octave=6, quarterLength=.125) ) #4.5
s.append( note.Note('f', octave=6, quarterLength=.5) )
s.append( note.Note('d', octave=6, quarterLength=.5) ) # 5.5
s.append( note.Rest(quarterLength=1.0)) #6.5

s.append( note.Note('a', octave=4, quarterLength=.125) )
s.append( note.Note('a-', octave=4, quarterLength=.125) )
s.append( note.Note('a', octave=4, quarterLength=.125) )
s.append( note.Note('a-', octave=4, quarterLength=.125) )
s.append( note.Note('f', octave=4, quarterLength=.5) )
s.append( note.Rest(quarterLength=1.0))


s.append( note.Note('f', octave=4, quarterLength=.125) )
s.append( note.Note('f-', octave=4, quarterLength=.125) )
s.append( note.Note('f', octave=4, quarterLength=.125) )
s.append( note.Note('f-', octave=4, quarterLength=.125) )
s.append( note.Note('f', octave=4, quarterLength=.125) )
s.append( note.Note('g-', octave=4, quarterLength=.125) )
s.append( note.Note('g', octave=4, quarterLength=.125) )
s.append( note.Note('g-', octave=4, quarterLength=.125) )
s.append( note.Note('g', octave=4, quarterLength=.125) )
s.append( note.Note('a-', octave=4, quarterLength=.125) )
s.append( note.Note('a', octave=4, quarterLength=.125) )
s.append( note.Note('a-', octave=4, quarterLength=.125) )
s.append( note.Note('a', octave=4, quarterLength=.125) )
s.append( note.Note('a-', octave=4, quarterLength=.125) )
s.append( note.Note('b', octave=4, quarterLength=.5) )
s.append( note.Rest(quarterLength=0.5))

s.append( chord.Chord([ 
    note.Note('d', octave=2, quarterLength=1.0), # si(b) RE(d) FA(f)
    note.Note('b', octave=2, quarterLength=1.0),
    note.Note('f', octave=3, quarterLength=1.0),
])  )
s.append( chord.Chord([ 
    note.Note('c', octave=2, quarterLength=1.0),
    note.Note('d', octave=2, quarterLength=1.0),
    note.Note('e-', octave=3, quarterLength=1.0),
])  )
s.append( chord.Chord([ 
    note.Note('a', octave=1, quarterLength=1.0),
    note.Note('c', octave=2, quarterLength=1.0),
    note.Note('e', octave=3, quarterLength=1.0),
])  )

s.append( note.Rest(quarterLength=2.0))

output.append(s)

s = stream.Part();

s.append( note.Rest(quarterLength=4))
s.append( note.Note('f', octave=4, quarterLength=.125) )
s.append( note.Note('f-', octave=4, quarterLength=.125) )
s.append( note.Note('f', octave=4, quarterLength=.125) )
s.append( note.Note('f-', octave=4, quarterLength=.125) )
s.append( note.Note('e', octave=4, quarterLength=.5) )
s.append( note.Rest(quarterLength=1.0))


s.append( note.Note('e', octave=4, quarterLength=.125) )
s.append( note.Note('e-', octave=4, quarterLength=.125) ) #3
s.append( note.Note('e', octave=4, quarterLength=.125) )
s.append( note.Note('e-', octave=4, quarterLength=.125) )
s.append( note.Note('e', octave=4, quarterLength=.125) )
s.append( note.Note('f-', octave=4, quarterLength=.125) ) #4
s.append( note.Note('f', octave=4, quarterLength=.125) )
s.append( note.Note('e-', octave=4, quarterLength=.125) ) 
s.append( note.Note('e', octave=4, quarterLength=.125) )
s.append( note.Note('e-', octave=4, quarterLength=.125) ) #4.5
s.append( note.Note('e', octave=4, quarterLength=.5) )
s.append( note.Note('c', octave=4, quarterLength=.5) ) # 5.5
s.append( note.Rest(quarterLength=1.0)) #6.5

s.append( note.Note('a', octave=4, quarterLength=.125) )
s.append( note.Note('a-', octave=4, quarterLength=.125) )
s.append( note.Note('a', octave=4, quarterLength=.125) )
s.append( note.Note('a-', octave=4, quarterLength=.125) )
s.append( note.Note('f', octave=4, quarterLength=.5) )
s.append( note.Rest(quarterLength=1.0))

nn = s.notes;

for n in s:
    if (n is note.Note):
        n.volume.velocity = 1

output.append(s)

volume.realizeVolume(output)

output.show('midi')

fp = output.write('midi', fp= _MUSIC_PATH_ + "1.mid")

# %%
s = stream.Stream()

s.append( note.Rest(quarterLength=1.0))

s.append( chord.Chord([ 
    note.Note('d', octave=2, quarterLength=1.5), # si(b) RE(d-) FA(f)
    note.Note('b', octave=2, quarterLength=1.5),
    note.Note('f', octave=3, quarterLength=1.5),
])  )
s.append( note.Rest(quarterLength=2.0))

s.append( chord.Chord([ 
    note.Note('c', octave=2, quarterLength=1.5),
    note.Note('d', octave=2, quarterLength=1.5),
    note.Note('e-', octave=3, quarterLength=1.5),
])  )
s.append( note.Rest(quarterLength=2.0))

s.append( chord.Chord([ 
    note.Note('a', octave=1, quarterLength=1.5),
    note.Note('c', octave=2, quarterLength=1.5),
    note.Note('e', octave=3, quarterLength=1.5),
])  )
s.append( note.Rest(quarterLength=2.0))

s.append( chord.Chord([ 
    note.Note('d-', octave=2, quarterLength=1.5),
    note.Note('b', octave=2, quarterLength=1.5),
    note.Note('f', octave=3, quarterLength=1.5),
])  )
s.append( note.Rest(quarterLength=2.0))

s.append( chord.Chord([ 
    note.Note('a', octave=1, quarterLength=2),
    note.Note('c', octave=2, quarterLength=2),
    note.Note('e', octave=2, quarterLength=2),
])  )

s.append( note.Rest(quarterLength=2.0))

s.show('midi')
fp = s.write('midi', fp= _MUSIC_PATH_ + "2.mid")
